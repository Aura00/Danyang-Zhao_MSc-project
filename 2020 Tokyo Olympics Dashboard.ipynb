# %%
import requests
import pandas as pd
import json
from PIL import Image
from pprint import pprint
from pyecharts import charts
from pyecharts import options as opts
from pyecharts.charts import *
from pyecharts.commons.utils import JsCode
from pyecharts.globals import ThemeType 
from pyecharts.components import Table
from pyecharts.options import ComponentTitleOpts
from bs4 import BeautifulSoup
import os

# %%
df = pd.DataFrame({"date":["2021/7/25","2021/7/26","2021/7/27","2021/7/28","2021/7/29","2021/7/30","2021/7/31","2021/8/1","2021/8/2","2021/8/3","2021/8/4","2021/8/5","2021/8/6","2021/8/7","2021/8/8"],
                       "gold":[0,4,1,5,0,1,9,2,3,3,3,1,3,2,2],
                       "silver":[1,2,2,4,1,2,0,5,2,12,1,0,5,2,0],
                       "bronze":[1,0,8,1,1,11,2,1,0,1,2,2,21,2,0]})
     
    
c = (
        Line(init_opts=opts.InitOpts(width="900px",height="500px"))
        .add_xaxis(df["date"].tolist())
        .add_yaxis('gold', df["gold"].tolist(),color="#667798",
            label_opts=opts.LabelOpts(
                formatter=JsCode(
                    'function(params){return params.value[2];}' #通过定义JavaScript回调函数自定义标签
                ),
                  is_show=False
            )
        )
        .add_yaxis('silver', df["silver"].tolist(),color="#0696FF",
            label_opts=opts.LabelOpts(
                formatter=JsCode(
                    'function(params){return params.value[2];}' 
                ),
                  is_show=False
            )
        )
         .add_yaxis('bronze', df["bronze"].tolist(),color="#0ABDBA",
            label_opts=opts.LabelOpts(
                formatter=JsCode(
                    'function(params){return params.value[2];}' 
                ),
                  is_show=False
            )
        )
        .set_global_opts(
            title_opts=opts.TitleOpts(title='Daily Medals for British Athletes '),
            legend_opts=opts.LegendOpts(type_="scroll", pos_left="90%", pos_top="10%",orient="vertical"),
            xaxis_opts=opts.AxisOpts(name='date'), 
            yaxis_opts=opts.AxisOpts(name='',axistick_opts=opts.AxisTickOpts(is_show=True),
                                    splitline_opts=opts.SplitLineOpts(is_show=True)),  
             )
            #legend_opts=opts.LegendOpts(is_show=True)
    )

    
    #return c
c.render('折线图1.html')
#os.system('折线图1.html')
# Out:
# 'C:\\Users\\Lenovo\\折线图1.html'

# %%
   
df1 = pd.DataFrame({"date":["2021/7/25","2021/7/26","2021/7/27","2021/7/28","2021/7/29","2021/7/30","2021/7/31","2021/8/1","2021/8/2","2021/8/3","2021/8/4","2021/8/5","2021/8/6","2021/8/7","2021/8/8"],
                       "total":[2,6,11,10,2,14,11,8,5,16,6,3,29,6,2],})
     
    
g = (
        EffectScatter(init_opts=opts.InitOpts(width="900px",height="500px"))
        .add_xaxis(df1["date"].tolist())
        .add_yaxis('total', df1["total"].tolist(),color="#0ABDBA",
            label_opts=opts.LabelOpts(
                formatter=JsCode(
                    'function(params){return params.value[2];}' 
                ),
                is_show=False
            )
        )
      
        .set_global_opts(
            title_opts=opts.TitleOpts(title='Daily Total Number of Medals for British Athletes '),
            legend_opts=opts.LegendOpts(type_="scroll", pos_left="92%", pos_top="10%",orient="vertical"),
            xaxis_opts=opts.AxisOpts(name='date'), 
            yaxis_opts=opts.AxisOpts(name='number',axistick_opts=opts.AxisTickOpts(is_show=True),
                                    splitline_opts=opts.SplitLineOpts(is_show=True)),  
            #legend_opts=opts.LegendOpts(is_show=True)
        )
    )
    
g.render('散点图1.html')
#os.system('散点图1.html')
# Out:
# 'C:\\Users\\Lenovo\\散点图1.html'

# %%
#1-8名柱形堆叠图"
#设置x轴数据
data=pd.DataFrame({
    "Delegation": ["USA","China", "Japan", "Great Britain","ROC","Australia","Netherlands","France"],
#设置total数据
    "total":[113,88,58,65,71,46,36,33],
#设置gold数据
    "gold":[39,38,27,22,20,17,10,10],
#设置silver数据
    "silver":[41,32,14,21,28,7,12,12],
#设置bronze数据
    "bronze":[33,18,17,22,23,22,14,11]})

toolbox_opts=opts.global_options.ToolBoxFeatureOpts(
    save_as_image = {"show": True, "title": "save as image", "type": "png"})

stack_bar = (
    Bar(init_opts=opts.InitOpts(width="1000px", height="500px",
                                animation_opts=opts.AnimationOpts(
                                    animation_delay=600, animation_easing="bounceIn")
                               )
       )
    
    .add_xaxis(data["Delegation"].tolist())
    .add_yaxis("gold", data["gold"].tolist(),color="#CC3300",bar_min_width=15,bar_max_width=70,)
    .add_yaxis("silver", data["silver"].tolist(),color="#B87333",bar_min_width=15,is_selected=True)
    .add_yaxis("bronze", data["bronze"].tolist(),bar_min_width=15,color="#C0C0C0")
    .add_yaxis("total", data["total"].tolist(),color="#FFD700",bar_min_width=15)
    #设置标签属性
    .set_series_opts(
        label_opts=opts.LabelOpts(is_show=True))     
    .set_global_opts(
    toolbox_opts=opts.ToolboxOpts(feature=toolbox_opts, orient = "vertical", pos_left = "92%"),
    title_opts=opts.TitleOpts(title='Country Ranking', subtitle='By gold medals',pos_left="10%"),
    legend_opts=opts.LegendOpts(pos_left="50%",textstyle_opts=opts.LabelOpts(font_size=18,font_family='Times New Roman',font_weight='bold')),#设置图例属性
       
        
    xaxis_opts=opts.AxisOpts(name_textstyle_opts=opts.TextStyleOpts(font_weight='bold',font_size=15,font_family='Times New Roman'),name="Country",axislabel_opts=opts.LabelOpts(font_size=15,font_family='Times New Roman',font_weight="normal" ,rotate=19),interval=115),
    yaxis_opts=opts.AxisOpts(name_textstyle_opts=opts.TextStyleOpts(font_weight='bold',font_size=15,font_family='Times New Roman'),axislabel_opts=opts.LabelOpts(font_size=15,font_style="normal",font_weight="normal" ,font_family='Times New Roman')))
)


stack_bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="af6024d7e94d433a880a353870624039" style="width:1000px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_af6024d7e94d433a880a353870624039 = echarts.init(
#                     document.getElementById('af6024d7e94d433a880a353870624039'), 'white', {renderer: 'canvas'});
#                 var option_af6024d7e94d433a880a353870624039 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "bounceIn",
#     "animationDelay": 600,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#FFD700",
#         "#C0C0C0",
#         "#B87333",
#         "#CC3300",
#         "#c23531",
#         "#2f4554",
# ...

# %%
#9-16名柱形堆叠图"
#设置x轴数据
data2=pd.DataFrame({
    "Delegation": ["Germany","Italy","Canada","Brazil","New Zealand","Cuba","Hungary","Korea"],
#设置total数据
    "total":[37,40,24,21,20,15,20,20],
#设置gold数据
    "gold":[10,10,7,7,7,7,6,6],
#设置silver数据
    "silver":[11,10,6,6,6,3,7,4],
#设置bronze数据
    "bronze":[16,20,11,8,7,5,7,10]})

stack_bar2 = (
     Bar(init_opts=opts.InitOpts(width="1000px", height="500px",
                                animation_opts=opts.AnimationOpts(
                                    animation_delay=600, animation_easing="bounceIn")
                               )
       )

    .add_xaxis(data2["Delegation"].tolist())
    .add_yaxis("gold", data2["gold"].tolist(),color="#CC3300",bar_min_width=15,bar_max_width=70,)
    .add_yaxis("silver", data2["silver"].tolist(),color="#B87333",bar_min_width=15,is_selected=True)
    .add_yaxis("bronze", data2["bronze"].tolist(),bar_min_width=15,color="#C0C0C0")
    .add_yaxis("total", data2["total"].tolist(),color="#FFD700",bar_min_width=15)
    #设置标签属性
    .set_series_opts(
        label_opts=opts.LabelOpts(is_show=True))     
)
toolbox_opts=opts.global_options.ToolBoxFeatureOpts(
    save_as_image = {"show": True, "title": "save as image", "type": "png"})
stack_bar2.set_global_opts(
    toolbox_opts=opts.ToolboxOpts(feature=toolbox_opts, orient = "vertical", pos_left = "92%"),
    title_opts=opts.TitleOpts(title='Country Ranking', subtitle='By gold medals',pos_left="10%"),
    legend_opts=opts.LegendOpts(pos_left="50%",textstyle_opts=opts.LabelOpts(font_size=18,font_family='Times New Roman',font_weight='bold')),#设置图例属性
        
        
    xaxis_opts=opts.AxisOpts(name_textstyle_opts=opts.TextStyleOpts(font_weight='bold',font_size=15,font_family='Times New Roman'),name="Country",axislabel_opts=opts.LabelOpts(font_size=15,font_family='Times New Roman',font_weight="normal" ,rotate=19),interval=115),
    yaxis_opts=opts.AxisOpts(name_textstyle_opts=opts.TextStyleOpts(font_weight='bold',font_size=15,font_family='Times New Roman'),axislabel_opts=opts.LabelOpts(font_size=15,font_style="normal",font_weight="normal" ,font_family='Times New Roman')))

#stack_bar=grid.add(stack_bar,grid_opts=opts.GridOpts(pos_top="10%"))#设置图例相对位置
stack_bar2.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="ca181c2e86344e969f80b6d7e414af19" style="width:1000px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_ca181c2e86344e969f80b6d7e414af19 = echarts.init(
#                     document.getElementById('ca181c2e86344e969f80b6d7e414af19'), 'white', {renderer: 'canvas'});
#                 var option_ca181c2e86344e969f80b6d7e414af19 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "bounceIn",
#     "animationDelay": 600,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#FFD700",
#         "#C0C0C0",
#         "#B87333",
#         "#CC3300",
#         "#c23531",
#         "#2f4554",
# ...

# %%
#17-24名柱形堆叠图"
#设置x轴数据
data3=pd.DataFrame({
    "Delegation": ["Poland","Czech Republic","Kenya","Norway","Jamaica","Spain","Sweden","Switzerland"],
#设置total数据
    "total":[14,11,10,8,9,17,9,13],
#设置gold数据
    "gold":[4,4,4,4,4,3,3,3],
#设置silver数据
    "silver":[5,4,4,2,1,8,6,4],
#设置bronze数据
    "bronze":[5,3,2,2,4,6,0,6]})

stack_bar3 = (
      Bar(init_opts=opts.InitOpts(width="1000px", height="500px",
                                animation_opts=opts.AnimationOpts(
                                    animation_delay=600, animation_easing="bounceIn")
                               )
       )

    .add_xaxis(data3["Delegation"].tolist())
    .add_yaxis("gold", data3["gold"].tolist(),color="#CC3300",bar_min_width=15,bar_max_width=70,)
    .add_yaxis("silver", data3["silver"].tolist(),color="#B87333",bar_min_width=15,is_selected=True)
    .add_yaxis("bronze", data3["bronze"].tolist(),bar_min_width=15,color="#C0C0C0")
    .add_yaxis("total", data3["total"].tolist(),color="#FFD700",bar_min_width=15)
    #设置标签属性
    .set_series_opts(
        label_opts=opts.LabelOpts(is_show=True))     
)
toolbox_opts=opts.global_options.ToolBoxFeatureOpts(
    save_as_image = {"show": True, "title": "save as image", "type": "png"})
stack_bar3.set_global_opts(
    toolbox_opts=opts.ToolboxOpts(feature=toolbox_opts, orient = "vertical", pos_left = "92%"),
    title_opts=opts.TitleOpts(title='Country Ranking', subtitle='By gold medals',pos_left="10%"),
    legend_opts=opts.LegendOpts(pos_left="50%",textstyle_opts=opts.LabelOpts(font_size=18,font_family='Times New Roman',font_weight='bold')),#设置图例属性
        
        
    xaxis_opts=opts.AxisOpts(name_textstyle_opts=opts.TextStyleOpts(font_weight='bold',font_size=15,font_family='Times New Roman'),name="Country",axislabel_opts=opts.LabelOpts(font_size=15,font_family='Times New Roman',font_weight="normal" ,rotate=19),interval=115),
    yaxis_opts=opts.AxisOpts(name_textstyle_opts=opts.TextStyleOpts(font_weight='bold',font_size=15,font_family='Times New Roman'),axislabel_opts=opts.LabelOpts(font_size=15,font_style="normal",font_weight="normal" ,font_family='Times New Roman')))

#stack_bar=grid.add(stack_bar,grid_opts=opts.GridOpts(pos_top="10%"))#设置图例相对位置
stack_bar3.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="71a4c24601474191aabef39c1ee997d2" style="width:1000px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_71a4c24601474191aabef39c1ee997d2 = echarts.init(
#                     document.getElementById('71a4c24601474191aabef39c1ee997d2'), 'white', {renderer: 'canvas'});
#                 var option_71a4c24601474191aabef39c1ee997d2 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "bounceIn",
#     "animationDelay": 600,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#FFD700",
#         "#C0C0C0",
#         "#B87333",
#         "#CC3300",
#         "#c23531",
#         "#2f4554",
# ...

# %%
#25-32名柱形堆叠图"
#设置x轴数据
data4=pd.DataFrame({
    "Delegation": ["Denmark","Croatia","Iran","Serbia","Belgium","Bulgaria","Slovenia","Uzbekistan"],
#设置total数据
    "total":[11,8,7,9,7,6,5,5],
#设置gold数据
    "gold":[3,3,3,3,3,3,3,3],
#设置silver数据
    "silver":[4,3,2,1,1,1,1,0],
#设置bronze数据
    "bronze":[4,2,2,5,3,2,1,2]})

stack_bar4 = (
      Bar(init_opts=opts.InitOpts(width="1000px", height="500px",
                                animation_opts=opts.AnimationOpts(
                                    animation_delay=600, animation_easing="bounceIn")
                               )
       )

    .add_xaxis(data4["Delegation"].tolist())
    .add_yaxis("gold", data4["gold"].tolist(),color="#CC3300",bar_min_width=15,bar_max_width=70,)
    .add_yaxis("silver", data4["silver"].tolist(),color="#B87333",bar_min_width=15,is_selected=True)
    .add_yaxis("bronze", data4["bronze"].tolist(),bar_min_width=15,color="#C0C0C0")
    .add_yaxis("total", data4["total"].tolist(),color="#FFD700",bar_min_width=15)
    #设置标签属性
    .set_series_opts(
        label_opts=opts.LabelOpts(is_show=True))     
)
toolbox_opts=opts.global_options.ToolBoxFeatureOpts(
    save_as_image = {"show": True, "title": "save as image", "type": "png"})
stack_bar4.set_global_opts(
    toolbox_opts=opts.ToolboxOpts(feature=toolbox_opts, orient = "vertical", pos_left = "92%"),
    title_opts=opts.TitleOpts(title='Country Ranking', subtitle='By gold medals',pos_left="10%"),
    legend_opts=opts.LegendOpts(pos_left="50%",textstyle_opts=opts.LabelOpts(font_size=18,font_family='Times New Roman',font_weight='bold')),#设置图例属性
       
        
    xaxis_opts=opts.AxisOpts(name_textstyle_opts=opts.TextStyleOpts(font_weight='bold',font_size=15,font_family='Times New Roman'),name="Country",axislabel_opts=opts.LabelOpts(font_size=15,font_family='Times New Roman',font_weight="normal" ,rotate=19),interval=115),
    yaxis_opts=opts.AxisOpts(name_textstyle_opts=opts.TextStyleOpts(font_weight='bold',font_size=15,font_family='Times New Roman'),axislabel_opts=opts.LabelOpts(font_size=15,font_style="normal",font_weight="normal" ,font_family='Times New Roman')))

#stack_bar=grid.add(stack_bar,grid_opts=opts.GridOpts(pos_top="10%"))#设置图例相对位置
stack_bar4.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="dba6b64036ff42489a0f4c91ea7ee270" style="width:1000px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_dba6b64036ff42489a0f4c91ea7ee270 = echarts.init(
#                     document.getElementById('dba6b64036ff42489a0f4c91ea7ee270'), 'white', {renderer: 'canvas'});
#                 var option_dba6b64036ff42489a0f4c91ea7ee270 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "bounceIn",
#     "animationDelay": 600,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#FFD700",
#         "#C0C0C0",
#         "#B87333",
#         "#CC3300",
#         "#c23531",
#         "#2f4554",
# ...

# %%
#33-40名柱形堆叠图"
#设置x轴数据
data5=pd.DataFrame({
    "Delegation": ["Georgia","Chinese Taipei","Turkey","Greece","Uganda","Ecuador","Ireland","Israel"],
#设置total数据
    "total":[8,12,13,4,4,3,4,4],
#设置gold数据
    "gold":[2,2,2,2,2,2,2,2],
#设置silver数据
    "silver":[5,4,2,1,1,1,0,0],
#设置bronze数据
    "bronze":[1,6,9,1,1,0,2,2]})

stack_bar5 = (
       Bar(init_opts=opts.InitOpts(width="1000px", height="500px",
                                animation_opts=opts.AnimationOpts(
                                    animation_delay=600, animation_easing="bounceIn")
                               )
       )

    .add_xaxis(data5["Delegation"].tolist())
    .add_yaxis("gold", data5["gold"].tolist(),color="#CC3300",bar_min_width=15,bar_max_width=70,)
    .add_yaxis("silver", data5["silver"].tolist(),color="#B87333",bar_min_width=15,is_selected=True)
    .add_yaxis("bronze", data5["bronze"].tolist(),bar_min_width=15,color="#C0C0C0")
    .add_yaxis("total", data5["total"].tolist(),color="#FFD700",bar_min_width=15)
    #设置标签属性
    .set_series_opts(
        label_opts=opts.LabelOpts(is_show=True))     
)
toolbox_opts=opts.global_options.ToolBoxFeatureOpts(
    save_as_image = {"show": True, "title": "save as image", "type": "png"})
stack_bar5.set_global_opts(
    toolbox_opts=opts.ToolboxOpts(feature=toolbox_opts, orient = "vertical", pos_left = "92%"),
    title_opts=opts.TitleOpts(title='Country Ranking', subtitle='By gold medals',pos_left="10%"),
    legend_opts=opts.LegendOpts(pos_left="50%",textstyle_opts=opts.LabelOpts(font_size=18,font_family='Times New Roman',font_weight='bold')),#设置图例属性
      
        
    xaxis_opts=opts.AxisOpts(name_textstyle_opts=opts.TextStyleOpts(font_weight='bold',font_size=15,font_family='Times New Roman'),name="Country",axislabel_opts=opts.LabelOpts(font_size=15,font_family='Times New Roman',font_weight="normal" ,rotate=19),interval=115),
    yaxis_opts=opts.AxisOpts(name_textstyle_opts=opts.TextStyleOpts(font_weight='bold',font_size=15,font_family='Times New Roman'),axislabel_opts=opts.LabelOpts(font_size=15,font_style="normal",font_weight="normal" ,font_family='Times New Roman')))

#stack_bar=grid.add(stack_bar,grid_opts=opts.GridOpts(pos_top="10%"))#设置图例相对位置
stack_bar5.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="1d92fd27fa3d4ff18390249067003ac1" style="width:1000px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_1d92fd27fa3d4ff18390249067003ac1 = echarts.init(
#                     document.getElementById('1d92fd27fa3d4ff18390249067003ac1'), 'white', {renderer: 'canvas'});
#                 var option_1d92fd27fa3d4ff18390249067003ac1 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "bounceIn",
#     "animationDelay": 600,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#FFD700",
#         "#C0C0C0",
#         "#B87333",
#         "#CC3300",
#         "#c23531",
#         "#2f4554",
# ...

# %%
#40-47名柱形堆叠图"
#设置x轴数据
data6=pd.DataFrame({
    "Delegation": ["Qatar","Bahamas","Kosovo","Ukraine","Belarus","Romania","Venezuela","India"],
#设置total数据
    "total":[3,2,2,19,7,4,4,7],
#设置gold数据
    "gold":[2,2,2,1,1,1,1,1],
#设置silver数据
    "silver":[0,0,0,6,3,3,3,2],
#设置bronze数据
    "bronze":[1,0,0,12,3,0,0,4]})

stack_bar6 = (
     Bar(init_opts=opts.InitOpts(width="1000px", height="500px",
                                animation_opts=opts.AnimationOpts(
                                    animation_delay=600, animation_easing="bounceIn")
                               )
       )

    .add_xaxis(data6["Delegation"].tolist())
    .add_yaxis("gold", data6["gold"].tolist(),color="#CC3300",bar_min_width=15,bar_max_width=70,)
    .add_yaxis("silver", data6["silver"].tolist(),color="#B87333",bar_min_width=15,is_selected=True)
    .add_yaxis("bronze", data6["bronze"].tolist(),bar_min_width=15,color="#C0C0C0")
    .add_yaxis("total", data6["total"].tolist(),color="#FFD700",bar_min_width=15)
    #设置标签属性
    .set_series_opts(
        label_opts=opts.LabelOpts(is_show=True))     
)
toolbox_opts=opts.global_options.ToolBoxFeatureOpts(
    save_as_image = {"show": True, "title": "save as image", "type": "png"})
stack_bar6.set_global_opts(
    toolbox_opts=opts.ToolboxOpts(feature=toolbox_opts, orient = "vertical", pos_left = "92%"),
    title_opts=opts.TitleOpts(title='Country Ranking', subtitle='By gold medals',pos_left="10%"),
    legend_opts=opts.LegendOpts(pos_left="50%",textstyle_opts=opts.LabelOpts(font_size=18,font_family='Times New Roman',font_weight='bold')),#设置图例属性
        
        
    xaxis_opts=opts.AxisOpts(name_textstyle_opts=opts.TextStyleOpts(font_weight='bold',font_size=15,font_family='Times New Roman'),name="Country",axislabel_opts=opts.LabelOpts(font_size=15,font_family='Times New Roman',font_weight="normal" ,rotate=19),interval=115),
    yaxis_opts=opts.AxisOpts(name_textstyle_opts=opts.TextStyleOpts(font_weight='bold',font_size=15,font_family='Times New Roman'),axislabel_opts=opts.LabelOpts(font_size=15,font_style="normal",font_weight="normal" ,font_family='Times New Roman')))

#stack_bar=grid.add(stack_bar,grid_opts=opts.GridOpts(pos_top="10%"))#设置图例相对位置
stack_bar6.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="42684a0a6615480c9e4f1b298f307636" style="width:1000px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_42684a0a6615480c9e4f1b298f307636 = echarts.init(
#                     document.getElementById('42684a0a6615480c9e4f1b298f307636'), 'white', {renderer: 'canvas'});
#                 var option_42684a0a6615480c9e4f1b298f307636 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "bounceIn",
#     "animationDelay": 600,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#FFD700",
#         "#C0C0C0",
#         "#B87333",
#         "#CC3300",
#         "#c23531",
#         "#2f4554",
# ...

# %%
#49-56名柱形堆叠图"
#设置x轴数据
data7=pd.DataFrame({
    "Delegation": ["Hong Kong, China","Philippines","Slovakia","South Africa","Austria","Egypt","Indonesia","Ethiopia"],
#设置total数据
    "total":[6,4,4,3,7,6,5,4],
#设置gold数据
    "gold":[1,1,1,1,1,1,1,1],
#设置silver数据
    "silver":[2,2,2,2,1,1,1,1],
#设置bronze数据
    "bronze":[3,1,1,0,5,4,3,2]})

stack_bar7 = (
    Bar(init_opts=opts.InitOpts(width="1000px", height="500px",
                                animation_opts=opts.AnimationOpts(
                                    animation_delay=600, animation_easing="bounceIn")
                               )
       )

    .add_xaxis(data7["Delegation"].tolist())
    .add_yaxis("gold", data7["gold"].tolist(),color="#CC3300",bar_min_width=15,bar_max_width=70,)
    .add_yaxis("silver", data7["silver"].tolist(),color="#B87333",bar_min_width=15,is_selected=True)
    .add_yaxis("bronze", data7["bronze"].tolist(),bar_min_width=15,color="#C0C0C0")
    .add_yaxis("total", data7["total"].tolist(),color="#FFD700",bar_min_width=15)
    #设置标签属性
    .set_series_opts(
        label_opts=opts.LabelOpts(is_show=True))     
)
toolbox_opts=opts.global_options.ToolBoxFeatureOpts(
    save_as_image = {"show": True, "title": "save as image", "type": "png"})
stack_bar7.set_global_opts(
    toolbox_opts=opts.ToolboxOpts(feature=toolbox_opts, orient = "vertical", pos_left = "92%"),
    title_opts=opts.TitleOpts(title='Country Ranking', subtitle='By gold medals',pos_left="10%"),
    legend_opts=opts.LegendOpts(pos_left="50%",textstyle_opts=opts.LabelOpts(font_size=18,font_family='Times New Roman',font_weight='bold')),#设置图例属性
       
        
    xaxis_opts=opts.AxisOpts(name_textstyle_opts=opts.TextStyleOpts(font_weight='bold',font_size=15,font_family='Times New Roman'),name="Country",axislabel_opts=opts.LabelOpts(font_size=15,font_family='Times New Roman',font_weight="normal" ,rotate=19),interval=115),
    yaxis_opts=opts.AxisOpts(name_textstyle_opts=opts.TextStyleOpts(font_weight='bold',font_size=15,font_family='Times New Roman'),axislabel_opts=opts.LabelOpts(font_size=15,font_style="normal",font_weight="normal" ,font_family='Times New Roman')))

#stack_bar=grid.add(stack_bar,grid_opts=opts.GridOpts(pos_top="10%"))#设置图例相对位置
stack_bar7.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="53a028c2aa0c4b048b6260fe8ae0a22d" style="width:1000px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_53a028c2aa0c4b048b6260fe8ae0a22d = echarts.init(
#                     document.getElementById('53a028c2aa0c4b048b6260fe8ae0a22d'), 'white', {renderer: 'canvas'});
#                 var option_53a028c2aa0c4b048b6260fe8ae0a22d = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "bounceIn",
#     "animationDelay": 600,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#FFD700",
#         "#C0C0C0",
#         "#B87333",
#         "#CC3300",
#         "#c23531",
#         "#2f4554",
# ...

# %%
#57-64名柱形堆叠图"
#设置x轴数据
data8=pd.DataFrame({
    "Delegation": ["Portugal","Tunisia","Estonia","Fiji","Latvia","Thailand","Bermuda","Morocco"],
#设置total数据
    "total":[4,2,2,2,2,2,1,1],
#设置gold数据
    "gold":[1,1,1,1,1,1,1,1],
#设置silver数据
    "silver":[1,1,0,0,0,0,0,0],
#设置bronze数据
    "bronze":[2,0,1,1,1,1,0,0]})

stack_bar8 = (
    Bar(init_opts=opts.InitOpts(width="1000px", height="500px",
                                animation_opts=opts.AnimationOpts(
                                    animation_delay=600, animation_easing="bounceIn")
                               )
       )

    .add_xaxis(data8["Delegation"].tolist())
    .add_yaxis("gold", data8["gold"].tolist(),color="#CC3300",bar_min_width=15,bar_max_width=70,)
    .add_yaxis("silver", data8["silver"].tolist(),color="#B87333",bar_min_width=15,is_selected=True)
    .add_yaxis("bronze", data8["bronze"].tolist(),bar_min_width=15,color="#C0C0C0")
    .add_yaxis("total", data8["total"].tolist(),color="#FFD700",bar_min_width=15)
    #设置标签属性
    .set_series_opts(
        label_opts=opts.LabelOpts(is_show=True))     
)
toolbox_opts=opts.global_options.ToolBoxFeatureOpts(
    save_as_image = {"show": True, "title": "save as image", "type": "png"})
stack_bar8.set_global_opts(
    toolbox_opts=opts.ToolboxOpts(feature=toolbox_opts, orient = "vertical", pos_left = "92%"),
    title_opts=opts.TitleOpts(title='Country Ranking', subtitle='By gold medals',pos_left="10%"),
    legend_opts=opts.LegendOpts(pos_left="50%",textstyle_opts=opts.LabelOpts(font_size=18,font_family='Times New Roman',font_weight='bold')),#设置图例属性
        
        
    xaxis_opts=opts.AxisOpts(name_textstyle_opts=opts.TextStyleOpts(font_weight='bold',font_size=15,font_family='Times New Roman'),name="Country",axislabel_opts=opts.LabelOpts(font_size=15,font_family='Times New Roman',font_weight="normal" ,rotate=19),interval=115),
    yaxis_opts=opts.AxisOpts(name_textstyle_opts=opts.TextStyleOpts(font_weight='bold',font_size=15,font_family='Times New Roman'),axislabel_opts=opts.LabelOpts(font_size=15,font_style="normal",font_weight="normal" ,font_family='Times New Roman')))

#stack_bar=grid.add(stack_bar,grid_opts=opts.GridOpts(pos_top="10%"))#设置图例相对位置
stack_bar8.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="dbf2ff2bd397492093463ef4017fedd1" style="width:1000px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_dbf2ff2bd397492093463ef4017fedd1 = echarts.init(
#                     document.getElementById('dbf2ff2bd397492093463ef4017fedd1'), 'white', {renderer: 'canvas'});
#                 var option_dbf2ff2bd397492093463ef4017fedd1 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "bounceIn",
#     "animationDelay": 600,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#FFD700",
#         "#C0C0C0",
#         "#B87333",
#         "#CC3300",
#         "#c23531",
#         "#2f4554",
# ...

# %%
#65-72名柱形堆叠图"
#设置x轴数据
data9=pd.DataFrame({
    "Delegation": ["Puerto Rico","Colombia","Azerbaijan","Dominican Republic","Armenia","Kyrgyzstan","Mongolia","Argentina"],
#设置total数据
    "total":[1,5,7,5,4,3,4,3],
#设置gold数据
    "gold":[1,0,0,0,0,0,0,0],
#设置silver数据
    "silver":[0,4,3,3,2,2,1,1],
#设置bronze数据
    "bronze":[0,1,4,2,2,1,3,2]})

stack_bar9 = (
      Bar(init_opts=opts.InitOpts(width="1000px", height="500px",
                                animation_opts=opts.AnimationOpts(
                                    animation_delay=600, animation_easing="bounceIn")
                               )
       )

    .add_xaxis(data9["Delegation"].tolist())
    .add_yaxis("gold", data9["gold"].tolist(),color="#CC3300",bar_min_width=15,bar_max_width=70,)
    .add_yaxis("silver", data9["silver"].tolist(),color="#B87333",bar_min_width=15,is_selected=True)
    .add_yaxis("bronze", data9["bronze"].tolist(),bar_min_width=15,color="#C0C0C0")
    .add_yaxis("total", data9["total"].tolist(),color="#FFD700",bar_min_width=15)
    #设置标签属性
    .set_series_opts(
        label_opts=opts.LabelOpts(is_show=True)) 
)
toolbox_opts=opts.global_options.ToolBoxFeatureOpts(
    save_as_image = {"show": True, "title": "save as image", "type": "png"})
stack_bar9.set_global_opts(
    toolbox_opts=opts.ToolboxOpts(feature=toolbox_opts, orient = "vertical", pos_left = "92%"),
    title_opts=opts.TitleOpts(title='Country Ranking', subtitle='By gold medals',pos_left="10%"),
    legend_opts=opts.LegendOpts(pos_left="50%",textstyle_opts=opts.LabelOpts(font_size=18,font_family='Times New Roman',font_weight='bold')),#设置图例属性
        
        
    xaxis_opts=opts.AxisOpts(name_textstyle_opts=opts.TextStyleOpts(font_weight='bold',font_size=15,font_family='Times New Roman'),name="Country",axislabel_opts=opts.LabelOpts(font_size=15,font_family='Times New Roman',font_weight="normal" ,rotate=19),interval=115),
    yaxis_opts=opts.AxisOpts(name_textstyle_opts=opts.TextStyleOpts(font_weight='bold',font_size=15,font_family='Times New Roman'),axislabel_opts=opts.LabelOpts(font_size=15,font_style="normal",font_weight="normal" ,font_family='Times New Roman')))

#stack_bar=grid.add(stack_bar,grid_opts=opts.GridOpts(pos_top="10%"))#设置图例相对位置
stack_bar9.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="a4aec70de1b34a9fab5d178f017187f7" style="width:1000px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_a4aec70de1b34a9fab5d178f017187f7 = echarts.init(
#                     document.getElementById('a4aec70de1b34a9fab5d178f017187f7'), 'white', {renderer: 'canvas'});
#                 var option_a4aec70de1b34a9fab5d178f017187f7 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "bounceIn",
#     "animationDelay": 600,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#FFD700",
#         "#C0C0C0",
#         "#B87333",
#         "#CC3300",
#         "#c23531",
#         "#2f4554",
# ...

# %%
#73-80名柱形堆叠图"
#设置x轴数据
data10=pd.DataFrame({
    "Delegation": ["San Marino","Jordan","Malaysia","Nigeria","Bahrain","Saudi Arabia","Lithuania","North Macedonia"],
#设置total数据
    "total":[3,2,2,2,1,1,1,1],
#设置gold数据
    "gold":[0,0,0,0,0,0,0,0],
#设置silver数据
    "silver":[1,1,1,1,1,1,1,1],
#设置bronze数据
    "bronze":[2,1,1,1,0,0,0,0]})

stack_bar10 = (
      Bar(init_opts=opts.InitOpts(width="1000px", height="500px",
                                animation_opts=opts.AnimationOpts(
                                    animation_delay=600, animation_easing="bounceIn")
                               )
       )

    .add_xaxis(data10["Delegation"].tolist())
    .add_yaxis("gold", data10["gold"].tolist(),color="#CC3300",bar_min_width=15,bar_max_width=70,)
    .add_yaxis("silver", data10["silver"].tolist(),color="#B87333",bar_min_width=15,is_selected=True)
    .add_yaxis("bronze", data10["bronze"].tolist(),bar_min_width=15,color="#C0C0C0")
    .add_yaxis("total", data10["total"].tolist(),color="#FFD700",bar_min_width=15)
    #设置标签属性
    .set_series_opts(
        label_opts=opts.LabelOpts(is_show=True))     
)
toolbox_opts=opts.global_options.ToolBoxFeatureOpts(
    save_as_image = {"show": True, "title": "save as image", "type": "png"})
stack_bar10.set_global_opts(
    toolbox_opts=opts.ToolboxOpts(feature=toolbox_opts, orient = "vertical", pos_left = "92%"),
    title_opts=opts.TitleOpts(title='Country Ranking', subtitle='By gold medals',pos_left="10%"),
    legend_opts=opts.LegendOpts(pos_left="50%",textstyle_opts=opts.LabelOpts(font_size=18,font_family='Times New Roman',font_weight='bold')),#设置图例属性
     
        
    xaxis_opts=opts.AxisOpts(name_textstyle_opts=opts.TextStyleOpts(font_weight='bold',font_size=15,font_family='Times New Roman'),name="Country",axislabel_opts=opts.LabelOpts(font_size=15,font_family='Times New Roman',font_weight="normal" ,rotate=19),interval=115),
    yaxis_opts=opts.AxisOpts(name_textstyle_opts=opts.TextStyleOpts(font_weight='bold',font_size=15,font_family='Times New Roman'),axislabel_opts=opts.LabelOpts(font_size=15,font_style="normal",font_weight="normal" ,font_family='Times New Roman')))

#stack_bar=grid.add(stack_bar,grid_opts=opts.GridOpts(pos_top="10%"))#设置图例相对位置
stack_bar10.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="54ca11a7bb8b4dcf84b36b8302cfb2b7" style="width:1000px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_54ca11a7bb8b4dcf84b36b8302cfb2b7 = echarts.init(
#                     document.getElementById('54ca11a7bb8b4dcf84b36b8302cfb2b7'), 'white', {renderer: 'canvas'});
#                 var option_54ca11a7bb8b4dcf84b36b8302cfb2b7 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "bounceIn",
#     "animationDelay": 600,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#FFD700",
#         "#C0C0C0",
#         "#B87333",
#         "#CC3300",
#         "#c23531",
#         "#2f4554",
# ...

# %%
#81-88名柱形堆叠图"
#设置x轴数据
data11=pd.DataFrame({
    "Delegation": ["Namibia","Turkmenistan","Kazakhstan","Mexico","Finland","Botswana","Burkina Faso","Cte d'Ivoire"],
#设置total数据
    "total":[1,1,8,4,2,1,1,1],
#设置gold数据
    "gold":[0,0,0,0,0,0,0,0],
#设置silver数据
    "silver":[1,1,0,0,0,0,0,0],
#设置bronze数据
    "bronze":[0,0,8,4,2,1,1,1]})

stack_bar11 = (
    Bar(init_opts=opts.InitOpts(width="1000px", height="500px",
                                animation_opts=opts.AnimationOpts(
                                    animation_delay=600, animation_easing="bounceIn")
                               )
       )#设置图表画布宽度

    .add_xaxis(data11["Delegation"].tolist())
    .add_yaxis("gold", data11["gold"].tolist(),color="#CC3300",bar_min_width=15,bar_max_width=70,)
    .add_yaxis("silver", data11["silver"].tolist(),color="#B87333",bar_min_width=15,is_selected=True)
    .add_yaxis("bronze", data11["bronze"].tolist(),bar_min_width=15,color="#C0C0C0")
    .add_yaxis("total", data11["total"].tolist(),color="#FFD700",bar_min_width=15)
    #设置标签属性
    .set_series_opts(
        label_opts=opts.LabelOpts(is_show=True))     
)
toolbox_opts=opts.global_options.ToolBoxFeatureOpts(
    save_as_image = {"show": True, "title": "save as image", "type": "png"})
stack_bar11.set_global_opts(
    toolbox_opts=opts.ToolboxOpts(feature=toolbox_opts, orient = "vertical", pos_left = "92%"),
    title_opts=opts.TitleOpts(title='Country Ranking', subtitle='By gold medals',pos_left="10%"),
    legend_opts=opts.LegendOpts(pos_left="50%",textstyle_opts=opts.LabelOpts(font_size=18,font_family='Times New Roman',font_weight='bold')),#设置图例属性
        #设置横纵坐标属性
        
    xaxis_opts=opts.AxisOpts(name_textstyle_opts=opts.TextStyleOpts(font_weight='bold',font_size=15,font_family='Times New Roman'),name="Country",axislabel_opts=opts.LabelOpts(font_size=15,font_family='Times New Roman',font_weight="normal" ,rotate=19),interval=115),
    yaxis_opts=opts.AxisOpts(name_textstyle_opts=opts.TextStyleOpts(font_weight='bold',font_size=15,font_family='Times New Roman'),axislabel_opts=opts.LabelOpts(font_size=15,font_style="normal",font_weight="normal" ,font_family='Times New Roman')))

#stack_bar=grid.add(stack_bar,grid_opts=opts.GridOpts(pos_top="10%"))#设置图例相对位置
stack_bar11.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="d2d4d8e78cd54c7aa52e74a3c4ea8d22" style="width:1000px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_d2d4d8e78cd54c7aa52e74a3c4ea8d22 = echarts.init(
#                     document.getElementById('d2d4d8e78cd54c7aa52e74a3c4ea8d22'), 'white', {renderer: 'canvas'});
#                 var option_d2d4d8e78cd54c7aa52e74a3c4ea8d22 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "bounceIn",
#     "animationDelay": 600,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#FFD700",
#         "#C0C0C0",
#         "#B87333",
#         "#CC3300",
#         "#c23531",
#         "#2f4554",
# ...

# %%
#89-93名柱形堆叠图"
#设置x轴数据
data12=pd.DataFrame({
    "Delegation": ["Ghana","Grenada","Kuwait","Republic of Moldova","Syrian Arab Republic"],
#设置total数据
    "total":[1,1,1,1,1],
#设置gold数据
    "gold":[0,0,0,0,0],
#设置silver数据
    "silver":[0,0,0,0,0],
#设置bronze数据
    "bronze":[1,1,1,1,1]})

stack_bar12 = (
      Bar(init_opts=opts.InitOpts(width="1000px", height="500px",
                                animation_opts=opts.AnimationOpts(
                                    animation_delay=600, animation_easing="bounceIn")
                               )
       )#设置图表画布宽度

    .add_xaxis(data12["Delegation"].tolist())
    .add_yaxis("gold", data12["gold"].tolist(),color="#CC3300",bar_min_width=15,bar_max_width=60,)
    .add_yaxis("silver", data12["silver"].tolist(),color="#B87333",bar_min_width=15,is_selected=True)
    .add_yaxis("bronze", data12["bronze"].tolist(),bar_min_width=15,color="#C0C0C0")
    .add_yaxis("total", data12["total"].tolist(),color="#FFD700",bar_min_width=15)
    #设置标签属性
    .set_series_opts(
        label_opts=opts.LabelOpts(is_show=True))     
)
toolbox_opts=opts.global_options.ToolBoxFeatureOpts(
    save_as_image = {"show": True, "title": "save as image", "type": "png"})
stack_bar12.set_global_opts(
    toolbox_opts=opts.ToolboxOpts(feature=toolbox_opts, orient = "vertical", pos_left = "92%"),
    title_opts=opts.TitleOpts(title='Country Ranking', subtitle='By gold medals',pos_left="10%"),
    legend_opts=opts.LegendOpts(pos_left="50%",textstyle_opts=opts.LabelOpts(font_size=18,font_family='Times New Roman',font_weight='bold')),#设置图例属性
        #设置横纵坐标属性
        
    xaxis_opts=opts.AxisOpts(name_textstyle_opts=opts.TextStyleOpts(font_weight='bold',font_size=15,font_family='Times New Roman'),name="Country",axislabel_opts=opts.LabelOpts(font_size=15,font_family='Times New Roman',font_weight="normal" ,rotate=19),interval=115),
    yaxis_opts=opts.AxisOpts(name_textstyle_opts=opts.TextStyleOpts(font_weight='bold',font_size=15,font_family='Times New Roman'),axislabel_opts=opts.LabelOpts(font_size=15,font_style="normal",font_weight="normal" ,font_family='Times New Roman')))

#stack_bar=grid.add(stack_bar,grid_opts=opts.GridOpts(pos_top="10%"))#设置图例相对位置
stack_bar12.render_notebook()
#stack_bar12.render("bar.html")
#os.system("bar.html")
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="0a7aaf0978e6488e8780d85908611af0" style="width:1000px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_0a7aaf0978e6488e8780d85908611af0 = echarts.init(
#                     document.getElementById('0a7aaf0978e6488e8780d85908611af0'), 'white', {renderer: 'canvas'});
#                 var option_0a7aaf0978e6488e8780d85908611af0 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "bounceIn",
#     "animationDelay": 600,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#FFD700",
#         "#C0C0C0",
#         "#B87333",
#         "#CC3300",
#         "#c23531",
#         "#2f4554",
# ...

# %%
tab1 = Tab()
tab1.add(stack_bar, "1-8")
tab1.add(stack_bar2, "9-16")
tab1.add(stack_bar3, "17-24")
tab1.add(stack_bar4, "25-32")
tab1.add(stack_bar5, "33-40")
tab1.add(stack_bar6, "41-48")
tab1.add(stack_bar7, "49-56")
tab1.add(stack_bar8, "55-64")
tab1.add(stack_bar9, "65-72")
tab1.add(stack_bar10, "73-80")
tab1.add(stack_bar11, "81-88")
tab1.add(stack_bar12, "89-93")
# 5. 渲染数据
tab1.render_embed()
tab1.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <style>
#         .tab {
#             overflow: hidden;
#             border: 1px solid #ccc;
#             background-color: #f1f1f1;
#         }
#
#         .tab button {
#             background-color: inherit;
#             float: left;
#             border: none;
#             outline: none;
#             cursor: pointer;
#             padding: 12px 16px;
#             transition: 0.3s;
#         }
#
#         .tab button:hover {
#             background-color: #ddd;
#         }
#
#         .tab button.active {
#             background-color: #ccc;
#         }
#
#         .chart-container {
#             display: none;
#             padding: 6px 12px;
#             border-top: none;
#         }
#     </style>
# <div class="tab">
# ...

# %%
timeline2 = Timeline(#is_auto_play=True,
                 #timeline_bottom=0,
                # timeline_play_interval=1000,
                 #width=800,height=600,
                 #timeline_left=80
                 )
timeline2.add(stack_bar,'')
timeline2.add(stack_bar2,'')
timeline2.add(stack_bar3,'')
timeline2.add(stack_bar4,'')
timeline2.add(stack_bar5,'')
timeline2.add(stack_bar6,'')
timeline2.add(stack_bar7,'')
timeline2.add(stack_bar8,'')
timeline2.add(stack_bar9,'')
timeline2.add(stack_bar10,'')
timeline2.add(stack_bar11,'')
timeline2.add(stack_bar12,'')
timeline2.add_schema(is_auto_play=True, play_interval=2000,pos_bottom=-20)
timeline2.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="353f658b205c4bc09160d9e0adb09c97" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_353f658b205c4bc09160d9e0adb09c97 = echarts.init(
#                     document.getElementById('353f658b205c4bc09160d9e0adb09c97'), 'white', {renderer: 'canvas'});
#                 var option_353f658b205c4bc09160d9e0adb09c97 = {
#     "baseOption": {
#         "series": [
#             {
#                 "type": "bar",
#                 "name": "gold",
#                 "legendHoverLink": true,
#                 "data": [
#                     0,
#                     0,
#                     0,
#                     0,
#                     0
#                 ],
#                 "showBackground": false,
# ...

# %%
#America


                 
df_A = pd.DataFrame({"Type":["Gold medals","Silver medals","Bronze medals"],
                    "Account":[39,41,33]
                  })
x_A=df_A["Type"].tolist()
y_A=df_A["Account"].tolist()
A = (
    Pie()
    .add("", [list(z) for z in zip(x_A, y_A)], 
    radius=["50%","80%"],
    center=["40%","60%"],) 
    .set_colors(["GOLD","SILVER","#B87333"])
    .set_global_opts(title_opts=opts.TitleOpts(title="Total:113",pos_bottom="35%",pos_left="15%",title_textstyle_opts= opts.TextStyleOpts(color="grey",font_size=13)),
                    legend_opts = opts.LegendOpts(is_show = False))  # 标题
    .set_series_opts(label_opts=opts.LabelOpts(is_show=False)
                   )  # 数据标签设置
)
A.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="3f9180a908c9416c8c24449ace5b8656" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_3f9180a908c9416c8c24449ace5b8656 = echarts.init(
#                     document.getElementById('3f9180a908c9416c8c24449ace5b8656'), 'white', {renderer: 'canvas'});
#                 var option_3f9180a908c9416c8c24449ace5b8656 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "GOLD",
#         "SILVER",
#         "#B87333"
#     ],
#     "series": [
#         {
#             "type": "pie",
# ...

# %%
#China
df_C = pd.DataFrame({"Type":["Gold medals","Silver medals","Bronze medals"],
                    "Account":[38,32,18]
                  })
x_C=df_C["Type"].tolist()
y_C=df_C["Account"].tolist()
C = (
    Pie()
    .add("", [list(z) for z in zip(x_C, y_C)], 
    radius=["50%","80%"],
    center=["40%","60%"],) 
    .set_colors(["GOLD","SILVER","#B87333"])
    .set_global_opts(title_opts=opts.TitleOpts(title="Total:88",pos_bottom="35%",pos_left="15%",title_textstyle_opts= opts.TextStyleOpts(color="grey",font_size=13)),
                    legend_opts = opts.LegendOpts(is_show = False))  # 标题
    .set_series_opts(label_opts=opts.LabelOpts(is_show=False)
                   )  # 数据标签设置
)
C.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="f2338e316df0418e9fdbf835d87bfcc1" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_f2338e316df0418e9fdbf835d87bfcc1 = echarts.init(
#                     document.getElementById('f2338e316df0418e9fdbf835d87bfcc1'), 'white', {renderer: 'canvas'});
#                 var option_f2338e316df0418e9fdbf835d87bfcc1 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "GOLD",
#         "SILVER",
#         "#B87333"
#     ],
#     "series": [
#         {
#             "type": "pie",
# ...

# %%
#ROC
df_R = pd.DataFrame({"Type":["Gold medals","Silver medals","Bronze medals"],
                    "Account":[20,28,23]
                  })
x_R=df_R["Type"].tolist()
y_R=df_R["Account"].tolist()
R = (
    Pie()
    .add("", [list(z) for z in zip(x_R, y_R)], 
    radius=["50%","80%"],
    center=["40%","60%"],) 
    .set_colors(["GOLD","SILVER","#B87333"])
    .set_global_opts(title_opts=opts.TitleOpts(title="Total:71",pos_bottom="35%",pos_left="15%",title_textstyle_opts= opts.TextStyleOpts(color="grey",font_size=13)),
                    legend_opts = opts.LegendOpts(is_show = False))  # 标题
    .set_series_opts(label_opts=opts.LabelOpts(is_show=False)
                   )  # 数据标签设置
)
R.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="02976d7b75f245769db414ccd6cddb43" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_02976d7b75f245769db414ccd6cddb43 = echarts.init(
#                     document.getElementById('02976d7b75f245769db414ccd6cddb43'), 'white', {renderer: 'canvas'});
#                 var option_02976d7b75f245769db414ccd6cddb43 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "GOLD",
#         "SILVER",
#         "#B87333"
#     ],
#     "series": [
#         {
#             "type": "pie",
# ...

# %%
#UK
df_U = pd.DataFrame({"Type":["Gold medals","Silver medals","Bronze medals"],
                    "Account":[22,21,22]
                  })
x_U=df_U["Type"].tolist()
y_U=df_U["Account"].tolist()
U = (
    Pie()
    .add("", [list(z) for z in zip(x_U, y_U)], 
    radius=["50%","80%"],
    center=["40%","60%"],) 
    .set_colors(["GOLD","SILVER","#B87333"])
    .set_global_opts(title_opts=opts.TitleOpts(title="Total:65",pos_bottom="35%",pos_left="15%",title_textstyle_opts= opts.TextStyleOpts(color="grey",font_size=13)),
                    legend_opts = opts.LegendOpts(is_show = False))  # 标题
    .set_series_opts(label_opts=opts.LabelOpts(is_show=False)
                   )  # 数据标签设置
)
U.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="d15d806e007c4019835de3396c6936bd" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_d15d806e007c4019835de3396c6936bd = echarts.init(
#                     document.getElementById('d15d806e007c4019835de3396c6936bd'), 'white', {renderer: 'canvas'});
#                 var option_d15d806e007c4019835de3396c6936bd = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "GOLD",
#         "SILVER",
#         "#B87333"
#     ],
#     "series": [
#         {
#             "type": "pie",
# ...

# %%
#Japan
df_J = pd.DataFrame({"Type":["Gold medals","Silver medals","Bronze medals"],
                    "Account":[27,14,17]
                  })
x_J=df_J["Type"].tolist()
y_J=df_J["Account"].tolist()
J = (
    Pie()
    .add("", [list(z) for z in zip(x_J, y_J)], 
    radius=["50%","80%"],
    center=["40%","60%"],) 
    .set_colors(["GOLD","SILVER","#B87333"])
    .set_global_opts(title_opts=opts.TitleOpts(title="Total:58",pos_bottom="35%",pos_left="15%",title_textstyle_opts= opts.TextStyleOpts(color="grey",font_size=13)),
                    legend_opts = opts.LegendOpts(is_show = False))  # 标题
    .set_series_opts(label_opts=opts.LabelOpts(is_show=False)
                   )  # 数据标签设置
)
J.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="31ad4b5bd69447e2b3dd350af33d731a" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_31ad4b5bd69447e2b3dd350af33d731a = echarts.init(
#                     document.getElementById('31ad4b5bd69447e2b3dd350af33d731a'), 'white', {renderer: 'canvas'});
#                 var option_31ad4b5bd69447e2b3dd350af33d731a = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "GOLD",
#         "SILVER",
#         "#B87333"
#     ],
#     "series": [
#         {
#             "type": "pie",
# ...

# %%
# Australia
df_Au = pd.DataFrame({"Type":["Gold medals","Silver medals","Bronze medals"],
                    "Account":[17,7,22]
                  })
x_Au=df_Au["Type"].tolist()
y_Au=df_Au["Account"].tolist()
Au = (
    Pie()
    .add("", [list(z) for z in zip(x_Au, y_Au)], 
    radius=["50%","80%"],
    center=["40%","60%"],) 
    .set_colors(["GOLD","SILVER","#B87333"])
    .set_global_opts(title_opts=opts.TitleOpts(title="Total:46",pos_bottom="35%",pos_left="15%",title_textstyle_opts= opts.TextStyleOpts(color="grey",font_size=13)),
                    legend_opts = opts.LegendOpts(is_show = False))  # 标题
    .set_series_opts(label_opts=opts.LabelOpts(is_show=False)
                   )  # 数据标签设置
)
Au.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="b7ae26a8220f40f7abd8802ef1d1d0d7" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_b7ae26a8220f40f7abd8802ef1d1d0d7 = echarts.init(
#                     document.getElementById('b7ae26a8220f40f7abd8802ef1d1d0d7'), 'white', {renderer: 'canvas'});
#                 var option_b7ae26a8220f40f7abd8802ef1d1d0d7 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "GOLD",
#         "SILVER",
#         "#B87333"
#     ],
#     "series": [
#         {
#             "type": "pie",
# ...

# %%
# Italy
df_It = pd.DataFrame({"Type":["Gold medals","Silver medals","Bronze medals"],
                    "Account":[10,10,20]
                  })
x_It=df_It["Type"].tolist()
y_It=df_It["Account"].tolist()
It = (
    Pie()
    .add("", [list(z) for z in zip(x_It, y_It)], 
    radius=["50%","80%"],
    center=["40%","60%"],) 
    .set_colors(["GOLD","SILVER","#B87333"])
    .set_global_opts(title_opts=opts.TitleOpts(title="Total:40",pos_bottom="35%",pos_left="15%",title_textstyle_opts= opts.TextStyleOpts(color="grey",font_size=13)),
                    legend_opts = opts.LegendOpts(is_show = False))  # 标题
    .set_series_opts(label_opts=opts.LabelOpts(is_show=False)
                   )  # 数据标签设置
)
It.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="c9591c4b46c9472d89edcd6ad75a4166" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_c9591c4b46c9472d89edcd6ad75a4166 = echarts.init(
#                     document.getElementById('c9591c4b46c9472d89edcd6ad75a4166'), 'white', {renderer: 'canvas'});
#                 var option_c9591c4b46c9472d89edcd6ad75a4166 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "GOLD",
#         "SILVER",
#         "#B87333"
#     ],
#     "series": [
#         {
#             "type": "pie",
# ...

# %%
# Germany
df_G = pd.DataFrame({"Type":["Gold medals","Silver medals","Bronze medals"],
                    "Account":[10,11,16]
                  })
x_G=df_G["Type"].tolist()
y_G=df_G["Account"].tolist()
G = (
    Pie()
    .add("", [list(z) for z in zip(x_G, y_G)], 
    radius=["50%","80%"],
    center=["40%","60%"],) 
    .set_colors(["GOLD","SILVER","#B87333"])
    .set_global_opts(title_opts=opts.TitleOpts(title="Total:37",pos_bottom="35%",pos_left="15%",title_textstyle_opts= opts.TextStyleOpts(color="grey",font_size=13)),
                    legend_opts = opts.LegendOpts(is_show = False))  # 标题
    .set_series_opts(label_opts=opts.LabelOpts(is_show=False)
                   )  # 数据标签设置
)
G.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="2dcea4dfa58c4f0f876a8c5a4c8a3374" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_2dcea4dfa58c4f0f876a8c5a4c8a3374 = echarts.init(
#                     document.getElementById('2dcea4dfa58c4f0f876a8c5a4c8a3374'), 'white', {renderer: 'canvas'});
#                 var option_2dcea4dfa58c4f0f876a8c5a4c8a3374 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "GOLD",
#         "SILVER",
#         "#B87333"
#     ],
#     "series": [
#         {
#             "type": "pie",
# ...

# %%
# Netherlands
df_N = pd.DataFrame({"Type":["Gold medals","Silver medals","Bronze medals"],
                    "Account":[10,12,14]
                  })
x_N=df_N["Type"].tolist()
y_N=df_N["Account"].tolist()
N = (
    Pie()
    .add("", [list(z) for z in zip(x_N, y_N)], 
    radius=["50%","80%"],
    center=["40%","60%"],) 
    .set_colors(["GOLD","SILVER","#B87333"])
    .set_global_opts(title_opts=opts.TitleOpts(title="Total:36",pos_bottom="35%",pos_left="15%",title_textstyle_opts= opts.TextStyleOpts(color="grey",font_size=13)),
                    legend_opts = opts.LegendOpts(is_show = False))  # 标题
    .set_series_opts(label_opts=opts.LabelOpts(is_show=False)
                   )  # 数据标签设置
)
N.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="d30163610c764e608c9f9e8f23dce380" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_d30163610c764e608c9f9e8f23dce380 = echarts.init(
#                     document.getElementById('d30163610c764e608c9f9e8f23dce380'), 'white', {renderer: 'canvas'});
#                 var option_d30163610c764e608c9f9e8f23dce380 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "GOLD",
#         "SILVER",
#         "#B87333"
#     ],
#     "series": [
#         {
#             "type": "pie",
# ...

# %%
# France
df_F = pd.DataFrame({"Type":["Gold medals","Silver medals","Bronze medals"],
                    "Account":[10,12,11]
                  })
x_F=df_F["Type"].tolist()
y_F=df_F["Account"].tolist()
F = (
    Pie()
    .add("", [list(z) for z in zip(x_F, y_F)], 
    radius=["50%","80%"],
    center=["40%","60%"],) 
    .set_colors(["GOLD","SILVER","#B87333"])
    .set_global_opts(title_opts=opts.TitleOpts(title="Total:33",pos_bottom="35%",pos_left="15%",title_textstyle_opts= opts.TextStyleOpts(color="grey",font_size=13)),
                    legend_opts = opts.LegendOpts(is_show = False))  # 标题
    .set_series_opts(label_opts=opts.LabelOpts(is_show=False)
                   )  # 数据标签设置
)
F.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="35b6f346b1b74f0aa32b2fb75b30ab75" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_35b6f346b1b74f0aa32b2fb75b30ab75 = echarts.init(
#                     document.getElementById('35b6f346b1b74f0aa32b2fb75b30ab75'), 'white', {renderer: 'canvas'});
#                 var option_35b6f346b1b74f0aa32b2fb75b30ab75 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "GOLD",
#         "SILVER",
#         "#B87333"
#     ],
#     "series": [
#         {
#             "type": "pie",
# ...

# %%
#导入全球
rank=pd.read_excel('C:/Users/Lenovo/Desktop/rank.xlsx')
#df=pd.DataFrame(medals, columns=["Rank of Total","Country Code", "Gold Medal","Silver Medal", "Bronze Medal","Total","Country"]
#rank

# %%
inner_x_data=rank['Country'][0:50].tolist()
inner_y_data=rank['Population'][0:50].tolist()
inner_data_pair = [list(z) for z in zip(inner_x_data, inner_y_data)]

outer_x_data =rank['Country'][51: ].tolist()
outer_y_data=rank['Population'][51: ].tolist()
outer_data_pair=[list(z) for z in zip(outer_x_data,outer_y_data)]
toolbox_opts=opts.global_options.ToolBoxFeatureOpts(
    save_as_image = {"show": True, "title": "save as image", "type": "png"})
p1 = (
     # 初始化
    Pie(init_opts=opts.InitOpts(
        width="900px",  # 设置图形大小
        height="500px",
       
       ))
  

    # 内部饼图
    .add(
        series_name="版本3.2.1",  # 图形名称
        #center=["40%", "80%"],  # 饼图位置
        data_pair=inner_data_pair,  # 系列数据项，格式为 [(key1, value1), (key2, value2)]
        radius=["25%", "52%"],  # 饼图半径 数组的第一项是内半径，第二项是外半径
        label_opts=opts.LabelOpts(position='inner'), # 标签设置在内部
    )

    # 外部嵌套环形图
    .add(
        series_name="版本3.2.9",  # 系列名称
        #center=["40%", "80%"],  # 饼图位置
        radius=["52%", "80%"],  # 饼图半径 数组的第一项是内半径，第二项是外半径
        data_pair=outer_data_pair, # 系列数据项，格式为 [(key1, value1), (key2, value2)]

        # 标签配置项 
        label_opts=opts.LabelOpts(
            position="outside",
            formatter="{a|{a}}{abg|}\n{hr|}\n {b|{b}: }{c}  {per|{d}%}  ",
            background_color="#eee",
            border_color="#aaa",
            border_width=1,
            border_radius=4,
            rich={
                "a": {"color": "#999",
                      "lineHeight": 22,
                      "align": "center"},

                "abg": {
                    "backgroundColor": "#e3e3e3",
                    "width": "100%",
                    "align": "right",
                    "height": 22,
                    "borderRadius": [4, 4, 0, 0],
                },


                "hr": {
                    "borderColor": "#aaa",
                    "width": "100%",
                    "borderWidth": 0.5,
                    "height": 0,
                },

                "b": {"fontSize": 16, "lineHeight": 33},

                "per": {
                    "color": "#eee",
                    "backgroundColor": "#334455",
                    "padding": [2, 4],
                    "borderRadius": 2,
                },
            },
        ),
    )

    # 全局配置项
    .set_global_opts(
        toolbox_opts=opts.ToolboxOpts(feature=toolbox_opts, orient = "vertical", pos_left = "15%",pos_top="10"),
        xaxis_opts = opts.AxisOpts(is_show = False),   #隐藏X轴刻度
        yaxis_opts = opts.AxisOpts(is_show = False),    #隐藏Y轴刻度
        legend_opts = opts.LegendOpts(is_show = True,type_="scroll", pos_left="80%", orient="vertical"),  #隐藏图例
        title_opts = opts.TitleOpts(title ="Number of Participants in Each Delegation ",pos_left="25%"),    #隐藏标题
                    )

    # 系统配置项
    .set_series_opts(
        tooltip_opts=opts.TooltipOpts(
            trigger="item",
            formatter="{b}: {c} ({d}%)"
        ),
        label_opts=opts.LabelOpts(is_show=False)  # 隐藏每个触角标签
    )
)

c.render_notebook()


 
p1.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="c8eb1f23f93a4c3a87d49d33456ae58a" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_c8eb1f23f93a4c3a87d49d33456ae58a = echarts.init(
#                     document.getElementById('c8eb1f23f93a4c3a87d49d33456ae58a'), 'white', {renderer: 'canvas'});
#                 var option_c8eb1f23f93a4c3a87d49d33456ae58a = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %%
#导入全球
entriesGender=pd.read_excel('C:/Users/Lenovo/Desktop/entriesGender.xlsx')
#df=pd.DataFrame(medals, columns=["Rank of Total","Country Code", "Gold Medal","Silver Medal", "Bronze Medal","Total","Country"]
#entriesGender

# %%
x_data=entriesGender['Discipline'].tolist()
y_data=entriesGender['Male'].tolist()
F1 = (
        Funnel()
        .add("", [list(z) for z in zip(x_data,y_data)])
        .set_global_opts(title_opts=opts.TitleOpts(title="Number of Male Athletes in Each Discipline",pos_left="25%"),
                       legend_opts=opts.LegendOpts(type_="scroll",pos_top="7%"),)
         .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
    )
F1.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="246f3b39e7b04ac0b831e361f8b072b6" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_246f3b39e7b04ac0b831e361f8b072b6 = echarts.init(
#                     document.getElementById('246f3b39e7b04ac0b831e361f8b072b6'), 'white', {renderer: 'canvas'});
#                 var option_246f3b39e7b04ac0b831e361f8b072b6 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %%
x_data2=entriesGender['Discipline'].tolist()
y_data2=entriesGender['Female'].tolist()
F2 = (
        Funnel()
        .add("", [list(z) for z in zip(x_data2,y_data2)])
        .set_global_opts(title_opts=opts.TitleOpts(title="Number of Female Athletes in Each Discipline",pos_left="25%"),
                        legend_opts=opts.LegendOpts(type_="scroll",pos_top="7%"),)
         .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
    )
F2.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="2d1305ceb9984520aa2dca0a5fc1a6f3" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_2d1305ceb9984520aa2dca0a5fc1a6f3 = echarts.init(
#                     document.getElementById('2d1305ceb9984520aa2dca0a5fc1a6f3'), 'white', {renderer: 'canvas'});
#                 var option_2d1305ceb9984520aa2dca0a5fc1a6f3 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %%
x_data3=entriesGender['Discipline'].tolist()
y_data3=entriesGender['Total'].tolist()
F3 = (
        Funnel()
        .add("", [list(z) for z in zip(x_data3,y_data3)])
        .set_global_opts(title_opts=opts.TitleOpts(title="Number of Athletes in Each Discipline",pos_left="28%"),
                       legend_opts=opts.LegendOpts(type_="scroll",pos_top="7%"),)
         .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
    )
F3.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="8ff19f4bee024c1e9e0ec0229123413d" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_8ff19f4bee024c1e9e0ec0229123413d = echarts.init(
#                     document.getElementById('8ff19f4bee024c1e9e0ec0229123413d'), 'white', {renderer: 'canvas'});
#                 var option_8ff19f4bee024c1e9e0ec0229123413d = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %%
timeline3 = Timeline(#is_auto_play=True,
                 #timeline_bottom=0,
                # timeline_play_interval=1000,
                 #width=800,height=600,
                 #timeline_left=80
                 )
timeline3.add(F1,'Male')
timeline3.add(F2,'Femal')
timeline3.add(F3,'Total')

timeline3.add_schema(is_auto_play=True, play_interval=2000,pos_bottom=0)
timeline3.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="d399e630899646049c66cab5ca810b29" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_d399e630899646049c66cab5ca810b29 = echarts.init(
#                     document.getElementById('d399e630899646049c66cab5ca810b29'), 'white', {renderer: 'canvas'});
#                 var option_d399e630899646049c66cab5ca810b29 = {
#     "baseOption": {
#         "series": [
#             {
#                 "type": "funnel",
#                 "data": [
#                     {
#                         "name": "3x3 Basketball",
#                         "value": 64
#                     },
#                     {
#                         "name": "Archery",
#                         "value": 128
#                     },
#                     {
# ...

# %%
x_data4=entriesGender['Discipline'].tolist()
y_data4=entriesGender['Gold'].tolist()
F4 = (
        Funnel()
        .add("", [list(z) for z in zip(x_data4,y_data4)],)
        .set_global_opts(title_opts=opts.TitleOpts(title="Number of Gold Medals in Each Discipline",pos_left="25%"),
                         legend_opts=opts.LegendOpts(type_="scroll",pos_top="7%"),)
         .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
    )
F4.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="1d070421b32f425d8de06fd0a0277eaa" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_1d070421b32f425d8de06fd0a0277eaa = echarts.init(
#                     document.getElementById('1d070421b32f425d8de06fd0a0277eaa'), 'white', {renderer: 'canvas'});
#                 var option_1d070421b32f425d8de06fd0a0277eaa = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %%
x_data5=entriesGender['Discipline'].tolist()
y_data5=entriesGender['Silver'].tolist()
F5 = (
        Funnel()
        .add("", [list(z) for z in zip(x_data5,y_data5)])
        .set_global_opts(title_opts=opts.TitleOpts(title="Number of Silver Medals in Each Discipline",pos_left="25%"),
                         legend_opts=opts.LegendOpts(type_="scroll",pos_top="7%"),)
         .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
    )
F5.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="a9886c9ae3ec41ac87d60264b97919d2" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_a9886c9ae3ec41ac87d60264b97919d2 = echarts.init(
#                     document.getElementById('a9886c9ae3ec41ac87d60264b97919d2'), 'white', {renderer: 'canvas'});
#                 var option_a9886c9ae3ec41ac87d60264b97919d2 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %%
x_data6=entriesGender['Discipline'].tolist()
y_data6=entriesGender['Bronze'].tolist()
F6 = (
        Funnel()
        .add("", [list(z) for z in zip(x_data6,y_data6)])
        .set_global_opts(title_opts=opts.TitleOpts(title="Number of Bronze Medals in Each Discipline",pos_left="25%"),
                        legend_opts=opts.LegendOpts(type_="scroll",pos_top="7%"),)
         .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
    )
F6.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="22b39d521b60420896a85c3ba575a393" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_22b39d521b60420896a85c3ba575a393 = echarts.init(
#                     document.getElementById('22b39d521b60420896a85c3ba575a393'), 'white', {renderer: 'canvas'});
#                 var option_22b39d521b60420896a85c3ba575a393 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %%
x_data7=entriesGender['Discipline'].tolist()
y_data7=entriesGender['Medals'].tolist()
F7 = (
        Funnel()
        .add("", [list(z) for z in zip(x_data7,y_data7)])
        .set_global_opts(title_opts=opts.TitleOpts(title="Number of Medals in Each Discipline",pos_left="25%"),
                        legend_opts=opts.LegendOpts(type_="scroll",pos_top="7%"),)
         .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
    )
F7.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="9f4ac2207d0f49ccbed9417367d5540d" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_9f4ac2207d0f49ccbed9417367d5540d = echarts.init(
#                     document.getElementById('9f4ac2207d0f49ccbed9417367d5540d'), 'white', {renderer: 'canvas'});
#                 var option_9f4ac2207d0f49ccbed9417367d5540d = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %%
timeline4 = Timeline(#is_auto_play=True,
                 #timeline_bottom=0,
                # timeline_play_interval=1000,
                 #width=800,height=600,
                 #timeline_left=80
                 )
timeline4.add(F4,'Gold Medals')
timeline4.add(F5,'Silver Medals')
timeline4.add(F6,'Bronze Medals')
timeline4.add(F7,'Total Medals')

timeline4.add_schema(is_auto_play=True, play_interval=2000,pos_bottom=0)
timeline4.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="8d7cc66c7340496889d30842564376dd" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_8d7cc66c7340496889d30842564376dd = echarts.init(
#                     document.getElementById('8d7cc66c7340496889d30842564376dd'), 'white', {renderer: 'canvas'});
#                 var option_8d7cc66c7340496889d30842564376dd = {
#     "baseOption": {
#         "series": [
#             {
#                 "type": "funnel",
#                 "data": [
#                     {
#                         "name": "3x3 Basketball",
#                         "value": 24
#                     },
#                     {
#                         "name": "Archery",
#                         "value": 30
#                     },
#                     {
# ...

# %%
name_map={
    "Canada": "Canada",
    "Turkmenistan": "Turkmenistan",
    "Saint Helena": "Saint Helena",
    "Lao PDR": "Lao PDR",
    "Lithuania": "Lithuania",
    "Ethiopia": "Ethiopia",
    "Argentina": "Argentina",
    "Burkina Faso": "Burkina Faso",
    "Bahrain": "Bahrain",
    "Saudi Arabia": "Saudi Arabia",
    "Slovenia": "Slovenia",
    "Germany": "Germany",
    "Spain": "Spain",
    "Netherlands": "Netherlands",
    "Jamaica": "Jamaica",
    "Bahamas": "Bahamas",
    "New Zealand": "New Zealand",
    "Czech Rep.": "Czech Republic",
    "India": "India",
    "Azerbaijan": "Azerbaijan",
    "Kenya": "Kenya",
    "Belarus": "Belarus",
    "Turkey": "Turkey",
    "Mongolia": "Mongolia",
    "France": "France",
    "Slovakia": "Slovakia",
    "Korea": "Korea",
    "China": "China",
    "Armenia": "Armenia",
    "Ukraine": "Ukraine",
    "Ghana": "Ghana",
    "Finland": "Finland",
    "Dominican Rep.": "Dominican Republic",
    "Indonesia": "Indonesia",
    "Sweden": "Sweden",
    "Russia": "Russia",
    "Bulgaria": "Bulgaria",
    "United States": "United States of America",
    "Romania": "Romania",
    "South Africa": "South Africa",
    "Fiji": "Fiji",
    "Malaysia": "Malaysia",
    "Austria": "Austria",
    "Uganda": "Uganda",
    "Japan": "Japan",
    "Brazil": "Brazil",
    "Kuwait": "Kuwait",
    "Ireland": "Ireland",
    "Italy": "Italy",
    "Nigeria": "Nigeria",
    "Ecuador": "Ecuador",
    "Australia": "Australia",
    "Iran": "Islamic Republic of Iran",
    "C?te d'Ivoire": "C?te d'Ivoire",
    "Puerto Rico": "",
    "Belgium": "Belgium",
    "Thailand": "Thailand",
    "Georgia": "Georgia",
    "Denmark": "Denmark",
    "Philippines": "Philippines",
    "Moldova": "Republic of Moldova",
    "Morocco": "Morocco",
    "Namibia": "Namibia",
    "Switzerland": "Switzerland",
    "Grenada": "Grenada",
    "Portugal": "Portugal",
    "Estonia": "Estonia",
    "Uzbekistan": "Uzbekistan",
    "Tunisia": "Tunisia",
    "Colombia": "Colombia",
    "Qatar": "Qatar",
    "Bermuda": "Bermuda",
    "Venezuela": "Venezuela",
    "Israel": "Israel",
    "Jordan": "Jordan",
    "Kazakhstan": "Kazakhstan",
    "Poland": "Poland",
    "Kyrgyzstan": "Kyrgyzstan",
    "Latvia": "Latvia",
    "Hungary": "Hungary",
    "Syria": "Syrian Arab Republic",
    "Mexico": "Mexico",
    "Egypt": "Egypt",
    "Cuba": "Cuba",
    "Serbia": "Serbia",
    "United Kingdom": "Great Britain",
    "Greece": "Greece",
    "Croatia": "Croatia",
    "Botswana": "Botswana",
    "Kosovo":"Kosovo",
    "San Marino":"San Marino",
    "Northern Macedonia":"North Macedonia"
}

# %%
#导入全球奖牌榜文件
medals=pd.read_excel('C:/Users/Lenovo/Desktop/medals.xlsx')
#df=pd.DataFrame(medals, columns=["Rank of Total","Country Code", "Gold Medal","Silver Medal", "Bronze Medal","Total","Country"])
#df
#medals

# %%
medals['Total'] = medals['Total'].astype('float')
# 基础数据
value = medals['Total']
attr = medals['Country']

data = []
for index in range(len(attr)):
    city_ionfo = [attr[index], value[index]]
    data.append(city_ionfo)
# 打开html
mc = (
   Map()
        .add("World Map", data, "world",is_map_symbol_show=False,
         is_roam=False, name_map=name_map)
        .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
        .set_global_opts(
        title_opts=opts.TitleOpts(title="World Distribution of Medals", pos_left="10%"),
        legend_opts=opts.LegendOpts(is_show=False),
        visualmap_opts=opts.VisualMapOpts(is_show=True, max_=120,
                                          is_piecewise=True,
                                          split_number = 8,
                                          range_color=['#FFDEAD','#FFA07A','#CD5C5C','#8B0000']
                                         ),

    )
        #.render()
)
mc.render_notebook()
# 打开html
#os.system("render.html")
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'world':'https://assets.pyecharts.org/assets/maps/world'
#         }
#     });
# </script>
#
#         <div id="c30b1266c3c5411e9ab486eba4928d44" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'world'], function(echarts) {
#                 var chart_c30b1266c3c5411e9ab486eba4928d44 = echarts.init(
#                     document.getElementById('c30b1266c3c5411e9ab486eba4928d44'), 'white', {renderer: 'canvas'});
#                 var option_c30b1266c3c5411e9ab486eba4928d44 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
# ...

# %%
medals['Gold Medal'] = medals['Gold Medal'].astype('float')
# 基础数据
value_gold = medals['Gold Medal']
data_gold = []
for index in range(len(attr)):
    city_ionfo = [attr[index], value_gold[index]]
    data_gold.append(city_ionfo)
    
mg = (
    Map()
        .add("World Map", data_gold, "world",is_map_symbol_show=False,
         is_roam=False, name_map=name_map)
        .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
        .set_global_opts(
        title_opts=opts.TitleOpts(title="World Distribution of Gold Medals",pos_left="10%"),
        #visualmap_opts=opts.VisualMapOpts(max_=200),
        legend_opts=opts.LegendOpts(is_show=False),
        visualmap_opts=opts.VisualMapOpts(is_show=True, max_=48,
                                          is_piecewise=True,
                                          split_number = 8,
                                          range_color=['#EEE8AA','#FFFF00','#FFD700','#B8860B']
                                         ),

    )
        #.render()
)
mg.render_notebook()
# 打开html
#os.system("render.html")
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'world':'https://assets.pyecharts.org/assets/maps/world'
#         }
#     });
# </script>
#
#         <div id="ebdd8211ac124fc79e45843ab90e0e85" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'world'], function(echarts) {
#                 var chart_ebdd8211ac124fc79e45843ab90e0e85 = echarts.init(
#                     document.getElementById('ebdd8211ac124fc79e45843ab90e0e85'), 'white', {renderer: 'canvas'});
#                 var option_ebdd8211ac124fc79e45843ab90e0e85 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
# ...

# %%
medals['Silver Medal'] = medals['Silver Medal'].astype('float')
# 基础数据
value_silver = medals['Silver Medal']
data_silver = []
for index in range(len(attr)):
    city_ionfo = [attr[index], value_silver[index]]
    data_silver.append(city_ionfo)
    
ms = (
    Map()
        .add("World Map", data_silver, "world",is_map_symbol_show=False,
         is_roam=False, name_map=name_map)
        .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
        .set_global_opts(
        title_opts=opts.TitleOpts(title="World Distribution of Silver Medal",pos_left="10%"),
        #visualmap_opts=opts.VisualMapOpts(max_=200),
        legend_opts=opts.LegendOpts(is_show=False),
        visualmap_opts=opts.VisualMapOpts(is_show=True, max_=42,
                                          is_piecewise=True,
                                          split_number = 7,
                                          range_color=['#DCDCDC','#888888','#708090']
                                         ),

    )
        #.render()
)
ms.render_notebook()
# 打开html
#os.system("render.html")
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'world':'https://assets.pyecharts.org/assets/maps/world'
#         }
#     });
# </script>
#
#         <div id="9bd5802d477c4a309aff67d69c521b88" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'world'], function(echarts) {
#                 var chart_9bd5802d477c4a309aff67d69c521b88 = echarts.init(
#                     document.getElementById('9bd5802d477c4a309aff67d69c521b88'), 'white', {renderer: 'canvas'});
#                 var option_9bd5802d477c4a309aff67d69c521b88 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
# ...

# %%
medals['Bronze Medal'] = medals['Bronze Medal'].astype('float')
# 基础数据
value_bronze = medals['Bronze Medal']
data_bronze = []
for index in range(len(attr)):
    city_ionfo = [attr[index], value_bronze[index]]
    data_bronze.append(city_ionfo)
    
mb = (
    Map()
        .add("World Map", data_bronze, "world",is_map_symbol_show=False,
         is_roam=False, name_map=name_map)
        .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
        .set_global_opts(
        title_opts=opts.TitleOpts(title="World Distribution of Bronze Medal",pos_left="10%"),
        #visualmap_opts=opts.VisualMapOpts(max_=200),
        legend_opts=opts.LegendOpts(is_show=False),
        visualmap_opts=opts.VisualMapOpts(is_show=True, max_=40,
                                          is_piecewise=True,
                                          split_number = 8,
                                          range_color=['#FFDEAD','#F4A460','#CD853F','#8B4513']
                                         ),

    )
        #.render()
)
mb.render_notebook()
# 打开html
#os.system("render.html")
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'world':'https://assets.pyecharts.org/assets/maps/world'
#         }
#     });
# </script>
#
#         <div id="3f6ccd7c22614ad7b8d87b5e81781a60" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'world'], function(echarts) {
#                 var chart_3f6ccd7c22614ad7b8d87b5e81781a60 = echarts.init(
#                     document.getElementById('3f6ccd7c22614ad7b8d87b5e81781a60'), 'white', {renderer: 'canvas'});
#                 var option_3f6ccd7c22614ad7b8d87b5e81781a60 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
# ...

# %%
timeline1 = Timeline(#is_auto_play=True,
                 #timeline_bottom=0,
                # timeline_play_interval=1000,
                 #width=800,height=600,
                 #timeline_left=80
                 )
timeline1.add(mc,'Total')
timeline1.add(mg,'Gold Medal')
timeline1.add(ms,'Silver Medal')
timeline1.add(mb,'Bronze Medal')
timeline1.add_schema(is_auto_play=True, play_interval=2000)
timeline1.render("render.html")#保存为html类型
#os.system("render.html")
# Out:
# 'C:\\Users\\Lenovo\\render.html'

# %%
table1=Table()
headers1=["Name","Medal type","Date","Discipline"]
rows1=[
     ["PIDCOCK Thomas","Gold Medal","2021/7/26","Cycling Mountain Bike"],
    ["DALEY Thomas","Gold Medal","2021/7/26","Diving"],
    ["LEE Matty","Gold Medal","2021/7/26","Diving"],
    ["PEATY Adam","Gold Medal","2021/7/26","Swimming"],
    ["DEAN Tom","Gold Medal","2021/7/27","Swimming"],
     ["SCOTT Duncan","Gold Medal","2021/7/28","Swimming"],
    ["DEAN Tom","Gold Medal","2021/7/28","Swimming"],
    ["JARVIS Calum","Gold Medal","2021/7/28","Swimming"],
    ["GUY James","Gold Medal","2021/7/28","Swimming"],
    ["RICHARDS Matthew","Gold Medal","2021/7/28","Swimming"],
    ["SHRIEVER Bethany","Gold Medal","2021/7/30","Cycling BMX Racing"],
    
    ["ANDERSON Freya","Gold Medal","2021/7/31","Swimming"],
    ["DAWSON Kathleen","Gold Medal","2021/7/31","Swimming"],
    ["GUY James","Gold Medal","2021/7/31","Swimming"],
    ["HOPKIN Anna","Gold Medal","2021/7/31","Swimming"],
    ["PEATY Adam","Gold Medal","2021/7/31","Swimming"],
    ["TAYLOR-BROWN Georgia","Gold Medal","2021/7/31","Triathlon"],
    ["YEE Alex","Gold Medal","2021/7/31","Triathlon"],
    ["BROWNLEE Jonathan","Gold Medal","2021/7/31","Triathlon"],
    ["LEARMONTH Jessica","Gold Medal","2021/7/31","Triathlon"],
    ["WHITLOCK Max","Gold Medal","2021/8/1","Artistic Gymnastics"],
   
    ["WORTHINGTON Charlotte","Gold Medal","2021/8/1","Cycling BMX Freestyle"],
    

    ["McEWEN Tom","Gold Medal","2021/8/2","Equestrian"],
    ["TOWNEND Oliver","Gold Medal","2021/8/2","Equestrian"],
    ["COLLETT Laura","Gold Medal","2021/8/2","Equestrian"],
   
    ["SCOTT Giles","Gold Medal","2021/8/3","Sailing"],
    ["BITHELL Stuart","Gold Medal","2021/8/3","Sailing"],
    ["FLETCHER Dylan","Gold Medal","2021/8/3","Sailing"],
   
    ["MAHER Ben","Gold Medal","2021/8/4","Equestrian"],
    ["McINTYRE Eilidh","Gold Medal","2021/8/4","Sailing"],
    ["MILLS Hannah","Gold Medal","2021/8/4","Sailing"],
   
    ["WALLS Matthew","Gold Medal","2021/8/5","Cycling Track"],
    
    ["ARCHIBALD Katie","Gold Medal","2021/8/6","Cycling Track"],
    ["KENNY Laura","Gold Medal","2021/8/6","Cycling Track"],
  
    
    ["FRENCH Kate","Gold Medal","2021/8/6","Modern Pentathlon"],
   
    ["YAFAI Galal","Gold Medal","2021/8/7","Boxing"],
   
    ["CHOONG Joseph","Gold Medal","2021/8/7","Modern Pentathlon"],    
    ["PRICE Lauren","Gold Medal","2021/8/8","Boxing"],
    ["KENNY Jason","Gold Medal","2021/8/8","Cycling Track"]]
table1.add(headers1,rows1)
table1.set_global_opts(
    title_opts=ComponentTitleOpts(title="Detailed statistics of British gold medalists ",subtitle=" "),
 )
    

table1.render("table1.html")
os.system("table1.html")
# Out:
# 0

# %%
x_b1=["Caeleb Dressel","Emma Mckeon","Kaylee Mckeown","San An","Elaine Thompson-Herah","Lisa Carrington","Katie Ledecky","Yufei Zhang","Ariarne Titmus","Daiki Hashimoto"]
y_b1=[5,4,3,3,3,3,2,2,2,2] #muber of gold medals
y_b2=[0,0,0,0,0,0,2,2,1,1] #number of silver medals
y_b3=[0,3,1,0,0,0,0,0,1,0]  #number of bronze medals

toolbox_opts=opts.global_options.ToolBoxFeatureOpts(
    save_as_image = {"show": True, "title": "save as image", "type": "png"})
bar1=Bar().add_xaxis(x_b1)
bar1.add_yaxis('Gold medals',y_b1,color="#B87333",bar_max_width=15,
                markpoint_opts=opts.MarkPointOpts(data=[opts.MarkPointItem(type_='max')],
                                                 symbol_size=60))
bar1.add_yaxis('Silver medals',y_b2,color="Silver",bar_max_width=15,
                markpoint_opts=opts.MarkPointOpts(data=[opts.MarkPointItem(type_='max')],
                                                 symbol_size=60))
bar1.add_yaxis('Bronze medals',y_b3,color="Gold",bar_max_width=15,
                markpoint_opts=opts.MarkPointOpts(data=[opts.MarkPointItem(type_='max')],
                                                 symbol_size=60))
bar1.set_series_opts(label_opts=opts.LabelOpts(is_show=False, position='right'))
bar1.set_global_opts(
    toolbox_opts=opts.ToolboxOpts(feature=toolbox_opts, orient = "vertical", pos_left = "95%",pos_top="6%"),
    xaxis_opts=opts.AxisOpts(axislabel_opts=opts.LabelOpts(rotate=-15)),
    title_opts=opts.TitleOpts(title='Top Athletes by Gold Medals',pos_left="15%"),
                    legend_opts=opts.LegendOpts(is_show=True,pos_left="60%"),)

#bar1.reversal_axis() #翻转XY轴，将柱状图转换为条形图
bar1.render_notebook()
#os.system('折线图1.html')
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="03020467afd34a3ca04d2fa903f3dbc2" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_03020467afd34a3ca04d2fa903f3dbc2 = echarts.init(
#                     document.getElementById('03020467afd34a3ca04d2fa903f3dbc2'), 'white', {renderer: 'canvas'});
#                 var option_03020467afd34a3ca04d2fa903f3dbc2 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "Gold",
#         "Silver",
#         "#B87333",
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
# ...

# %%
page=(Page()
.add(timeline1)
#add(table1)
#.add(p1)
#.add(p2)
.add(timeline2)
.add(A)
.add(C)
.add(R)
.add(U)
.add(J)
.add(Au)
.add(It)
.add(G)
.add(N)
.add(F)          
.add(bar1)
.add(p1)
.add(timeline3)
.add(timeline4)
#.add(c)
#.add(g)
#.add(table1)
.render("Tokyo 2020 Olympics Dashboard Network.html"))
#os.system("Page1.html")

# %%
with open("Tokyo 2020 Olympics Dashboard Network.html", "r+", encoding='utf-8') as html:
    html_bf = BeautifulSoup(html, 'lxml')
    divs = html_bf.select('.chart-container')
    divs[0]["style"] = "width:950px;height:500px;position:absolute;top:100px;left:10px;border-style:solid;border-color:#FFFFFF;border-width:3px;"
   # divs[1]["style"] = "width:750px;height:350px;position:absolute;top:720px;left:10px;border-style:solid;border-color:#afdfe4;border-width:3px;background-color:#afdfe4;"
   #divs[2]["style"] = "width:680px;height:350px;position:absolute;top:720px;left:760px;border-style:solid;border-color:#afdfe4;border-width:3px;background-color:#afdfe4;"
    divs[1]["style"] = "width:950px;height:500px;position:absolute;top:650px;left:10px;border-style:solid;border-color:#FFFFFF;border-width:3px;"
    
    divs[2]["style"] = "width:165px;height:165px;position:absolute;top:100px;left:1200px;border-style:solid;border-color:#FFFFFF;border-width:3px;"
    
    divs[3]["style"] = "width:165px;height:165px;position:absolute;top:272px;left:1200px;border-style:solid;border-color:#FFFFFF;border-width:3px;"
    
    divs[4]["style"] = "width:165px;height:165px;position:absolute;top:445px;left:1200px;border-style:solid;border-color:#FFFFFF;border-width:3px;"
   
    divs[5]["style"] = "width:165px;height:165px;position:absolute;top:620px;left:1200px;border-style:solid;border-color:#FFFFFF;border-width:3px;"
    divs[6]["style"] = "width:165px;height:165px;position:absolute;top:800px;left:1200px;border-style:solid;border-color:#FFFFFF;border-width:3px;"
   
    divs[7]["style"] = "width:165px;height:165px;position:absolute;top:100px;left:1650px;border-style:solid;border-color:#FFFFFF;border-width:3px;"
    divs[8]["style"] = "width:165px;height:165px;position:absolute;top:272px;left:1650px;border-style:solid;border-color:#FFFFFF;border-width:3px;"
    divs[9]["style"] = "width:165px;height:165px;position:absolute;top:445px;left:1650px;border-style:solid;border-color:#FFFFFF;border-width:3px;"
    divs[10]["style"] = "width:165px;height:165px;position:absolute;top:620px;left:1650px;border-style:solid;border-color:#FFFFFF;border-width:3px;"
    divs[11]["style"] = "width:165px;height:165px;position:absolute;top:800px;left:1650px;border-style:solid;border-color:#FFFFFF;border-width:3px;"
   
    divs[12]["style"] = "width:950px;height:500px;position:absolute;top:1190px;left:10px;border-style:solid;border-color:#FFFFFF;border-width:3px;"
    
    divs[13]["style"] = "width:950px;height:500px;position:absolute;top:1190px;left:980px;border-style:solid;border-color:#FFFFFF;border-width:3px;"
    divs[14]["style"] = "width:950px;height:500px;position:absolute;top:1750px;left:10px;border-style:solid;border-color:#FFFFFF;border-width:3px;"
    divs[15]["style"] = "width:950px;height:500px;position:absolute;top:1750px;left:980px;border-style:solid;border-color:#FFFFFF;border-width:3px;"
    
    #divs[7]["style"] = "width:600px;height:900px;position:absolute;top:1080px;left:800px;border-style:solid;border-color:#FFFFFF;border-width:3px;"
   

    body = html_bf.find("body")
    
    body["style"] = "background-color:#FFFFFF;"
    
    div_top="<div style=\"width:400px;height:50px;position:absolute;top:100px;left:970px\">\n<span style=\"font-size:18px;font face=\'Times New Roman\'\"><b>Top Countries by Total Medals</b></div>"
    div_US="<div style=\"width:60px;height:40px;position:absolute;top:160px;left:970px\">\n<span style=\"font-size:15px;font face=\'Times New Roman\';color:#FFD700\"><b>1 United States</b></div>"
    div_img1="<div style=\"width:113px;height:60px;position:absolute;top:160px;left:1060px;background:url(images/US.JPEG)\"></div>"
    body.insert(0,BeautifulSoup(div_img1,"lxml").div)  
    body.insert(1,BeautifulSoup(div_US,"lxml").div)  
    body.insert(2,BeautifulSoup(div_top,"lxml").div)  
    
    div_Au="<div style=\"width:60px;height:40px;position:absolute;top:160px;left:1420px\">\n<span style=\"font-size:15px;font face=\'Times New Roman\';color:#FFD700\"><b>6 Australia</b></div>"
    div_img6="<div style=\"width:113px;height:60px;position:absolute;top:160px;left:1510px;background:url(images/Australia.JPEG)\"></div>"
    body.insert(11,BeautifulSoup(div_img6,"lxml").div)  
    body.insert(12,BeautifulSoup(div_Au,"lxml").div)  
    
    div_C="<div style=\"width:60px;height:40px;position:absolute;top:330px;left:970px\">\n<span style=\"font-size:15px;font face=\'Times New Roman\';color:#FFD700\"><b>2</b>\n<span style=\"font-size:15px;font face=\'Times New Roman\';color:#FFD700\"><b>China</b></div>"
    div_img2="<div style=\"width:113px;height:71px;position:absolute;top:330px;left:1060px;background:url(images/China.JPEG)\"></div>"
    body.insert(3,BeautifulSoup(div_img2,"lxml").div)  
    body.insert(4,BeautifulSoup(div_C,"lxml").div) 
    
    div_It="<div style=\"width:60px;height:40px;position:absolute;top:330px;left:1420px\">\n<span style=\"font-size:15px;font face=\'Times New Roman\';color:#FFD700\"><b>7</b>\n<span style=\"font-size:15px;font face=\'Times New Roman\';color:#FFD700\"><b>Italy</b></div>"
    div_img7="<div style=\"width:113px;height:71px;position:absolute;top:330px;left:1510px;background:url(images/Italy.JPEG)\"></div>"
    body.insert(13,BeautifulSoup(div_img7,"lxml").div)  
    body.insert(14,BeautifulSoup(div_It,"lxml").div) 
    
    div_R="<div style=\"width:60px;height:40px;position:absolute;top:490px;left:970px\">\n<span style=\"font-size:15px;font face=\'Times New Roman\';color:#FFD700\"><b>3</b>\n<span style=\"font-size:15px;font face=\'Times New Roman\';color:#FFD700\"><b>Russia</b></div>"
    div_img3="<div style=\"width:113px;height:70px;position:absolute;top:490px;left:1060px;background:url(images/ROC.JPEG)\"></div>"
    body.insert(5,BeautifulSoup(div_img3,"lxml").div)  
    body.insert(6,BeautifulSoup(div_R,"lxml").div) 
    
    div_G="<div style=\"width:60px;height:40px;position:absolute;top:490px;left:1420px\">\n<span style=\"font-size:15px;font face=\'Times New Roman\';color:#FFD700\"><b>8</b>\n<span style=\"font-size:15px;font face=\'Times New Roman\';color:#FFD700\"><b>Germany</b></div>"
    div_img8="<div style=\"width:113px;height:70px;position:absolute;top:490px;left:1510px;background:url(images/Gemerny.JPEG)\"></div>"
    body.insert(15,BeautifulSoup(div_img8,"lxml").div)  
    body.insert(16,BeautifulSoup(div_G,"lxml").div) 
    
    div_U="<div style=\"width:60px;height:40px;position:absolute;top:675px;left:970px\">\n<span style=\"font-size:15px;font face=\'Times New Roman\';color:#FFD700\"><body><a href=\"British Award Details Dashboard Network.html\";target=\"_blank\"><b>4 Great Britain</b><a></div>"
    div_img4="<div style=\"width:113px;height:71px;position:absolute;top:675px;left:1060px;background:url(images/UK.JPEG)\"></div>"
    body.insert(7,BeautifulSoup(div_img4,"lxml").div)  
    body.insert(8,BeautifulSoup(div_U,"lxml").div) 
    
    div_N="<div style=\"width:60px;height:40px;position:absolute;top:675px;left:1420px\">\n<span style=\"font-size:15px;font face=\'Times New Roman\';color:#FFD700\"><b>9 Netherlands</b></div>"
    div_img9="<div style=\"width:113px;height:71px;position:absolute;top:675px;left:1510px;background:url(images/Netherlands.JPEG)\"></div>"
    body.insert(17,BeautifulSoup(div_img9,"lxml").div)  
    body.insert(18,BeautifulSoup(div_N,"lxml").div) 
    
    div_J="<div style=\"width:60px;height:40px;position:absolute;top:850px;left:970px\">\n<span style=\"font-size:15px;font face=\'Times New Roman\';color:#FFD700\"><b>5 Japan</b></div>"
    div_img5="<div style=\"width:113px;height:71px;position:absolute;top:850px;left:1060px;background:url(images/Japan.JPEG)\"></div>"
    body.insert(9,BeautifulSoup(div_img5,"lxml").div)  
    body.insert(10,BeautifulSoup(div_J,"lxml").div) 
    
    div_F="<div style=\"width:60px;height:40px;position:absolute;top:850px;left:1420px\">\n<span style=\"font-size:15px;font face=\'Times New Roman\';color:#FFD700\"><b>10 France</b></div>"
    div_img10="<div style=\"width:113px;height:71px;position:absolute;top:850px;left:1510px;background:url(images/France.JPEG)\"></div>"
    body.insert(19,BeautifulSoup(div_img10,"lxml").div)  
    body.insert(20,BeautifulSoup(div_F,"lxml").div) 
    
    div_log="<div style=\"width:90px;height:90px;position:absolute;top:5px;left:100px;background:url(images/log.JPEG)\"></div>"
    div_title="<div style=\"width:1980px;height:90px;position:absolute;top:15px;left:200px\">\n<span style=\"font-size:32px;font face=\'Times New Roman\';color:#000000\"><b>Tokyo 2020 Summer Olympics Dashboard Network </b></div>"  
    #修改页面背景色、追加标题
    body.insert(20,BeautifulSoup(div_log,"lxml").div)
    body.insert(0,BeautifulSoup(div_title,"lxml").div)
    title="Tokyo 2020 Olympics Dashboard Network.html"
    html_new = str(html_bf)
    html.seek(0, 0)
    html.truncate()
    html.write("<!DOCtype HTML>\
    \n<head><title>Tokyo 2020 Olympics Dashboard Network</title></head>")
    html.write(html_new)
    html.close()

# %%
os.system("Tokyo 2020 Olympics Dashboard Network.html")
# Out:
# 1
